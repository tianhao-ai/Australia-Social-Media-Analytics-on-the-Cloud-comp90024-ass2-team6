# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
df = pd.read_csv('EducationLevel_SUDO_after cleaning.csv')
jdf = df.to_json(orient='records')
#records = json.loads(jdf)
with open('EducationLevel_SUDO_after cleaning.json', 'w') as f:
    f.write(jdf)
df['X'] = df.index.values

# %%
with open('EducationLevel_SUDO_after cleaning.json', 'r') as f:
    for line in f:
        records = json.loads(jdf)

# %%
ax = df.plot(x = 'X', y=["Bachelar (%)", ' Postgraduate (%)', "Others (%)"], kind="bar", rot=90, stacked=True)
_ = ax.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
ax.set_xticklabels(df[' gccsa_name_2016'].values.tolist())
# Out:
# [Text(0, 0, 'Greater Sydney'),
#  Text(1, 0, 'Greater Melbourne'),
#  Text(2, 0, 'Greater Brisbane'),
#  Text(3, 0, 'Greater Adelaide'),
#  Text(4, 0, 'Greater Perth'),
#  Text(5, 0, 'Greater Hobart'),
#  Text(6, 0, 'Greater Darwin'),
#  Text(7, 0, 'Australian Capital Territory'),
#  Text(8, 0, 'Other Territories')]

# %%
records
# Out:
# [{' gccsa_code_2016': '1GSYD',
#   ' gccsa_name_2016': 'Greater Sydney',
#   'Bachelar (%)': 19.2,
#   ' Postgraduate (%)': 7.3,
#   'Others (%)': 73.5},
#  {' gccsa_code_2016': '2GMEL',
#   ' gccsa_name_2016': 'Greater Melbourne',
#   'Bachelar (%)': 18.5,
#   ' Postgraduate (%)': 6.4,
#   'Others (%)': 75.1},
#  {' gccsa_code_2016': '3GBRI',
#   ' gccsa_name_2016': 'Greater Brisbane',
#   'Bachelar (%)': 15.9,
#   ' Postgraduate (%)': 4.9,
#   'Others (%)': 79.2},
#  {' gccsa_code_2016': '4GADE',
#   ' gccsa_name_2016': 'Greater Adelaide',
#   'Bachelar (%)': 14.8,
#   ' Postgraduate (%)': 4.4,
#   'Others (%)': 80.8},
#  {' gccsa_code_2016': '5GPER',
#   ' gccsa_name_2016': 'Greater Perth',
#   'Bachelar (%)': 16.4,
#   ' Postgraduate (%)': 4.5,
#   'Others (%)': 79.1},
#  {' gccsa_code_2016': '6GHOB',
#   ' gccsa_name_2016': 'Greater Hobart',
#   'Bachelar (%)': 14.1,
#   ' Postgraduate (%)': 4.7,
#   'Others (%)': 81.2},
#  {' gccsa_code_2016': '7GDAR',
#   ' gccsa_name_2016': 'Greater Darwin',
#   'Bachelar (%)': 13.9,
#   ' Postgraduate (%)': 4.3,
#   'Others (%)': 81.8},
#  {' gccsa_code_2016': '8ACTE',
#   ' gccsa_name_2016': 'Australian Capital Territory',
#   'Bachelar (%)': 22.2,
#   ' Postgraduate (%)': 10.8,
#   'Others (%)': 67.0},
#  {' gccsa_code_2016': '9OTER',
#   ' gccsa_name_2016': 'Other Territories',
#   'Bachelar (%)': 8.6,
#   ' Postgraduate (%)': 2.0,
#   'Others (%)': 89.4}]

# %%
df.columns
# Out:
# Index([' gccsa_code_2016', ' gccsa_name_2016', 'Bachelar (%)',
#        ' Postgraduate (%)', 'Others (%)', 'X'],
#       dtype='object')
