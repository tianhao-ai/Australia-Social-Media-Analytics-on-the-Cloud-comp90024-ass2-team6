# %%
import couchdb
import json
username='group6'
passwd = '123456'
ip = '172.26.131.122'
hostName='http://{}:{}@{}:5984/'.format(username, passwd, ip)
couch = couchdb.Server(hostName)

# %% [markdown]
# # Count what are the top used bad words in each gcc

# %%
db = couch['bad_lang_tweet']

# %%
design_doc="whatbad"
def mapreduce(db):
    mapFunc = '''function(doc) {
                emit([doc.gcc, doc.bad_word], 1);
    }'''
    reduceFunc = 'function(keys, values) { return sum(values); }'
    ddoc = {
        "_id": "_design/{}".format(design_doc),
        "views": {
            "my_view": {
                "map": mapFunc,
                "reduce": reduceFunc
            }
        }
    }
    db.save(ddoc)

# %%
mapreduce(db)
# Out:
# ---------------------------------------------------------------------------
# ResourceConflict                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mapreduce(db)
#
# Cell In[4], line 16, in mapreduce(db)
#       6 reduceFunc = 'function(keys, values) { return sum(values); }'
#       7 ddoc = {
#       8     "_id": "_design/{}".format(design_doc),
#       9     "views": {
#    (...)
#      14     }
#      15 }
# ---> 16 db.save(ddoc)
#
# File /opt/homebrew/lib/python3.11/site-packages/couchdb/client.py:529, in Database.save(self, doc, **options)
#     527 else:
#     528     func = self.resource.post_json
# --> 529 _, _, data = func(body=doc, **options)
#     530 id, rev = data['id'], data.get('rev')
#     531 doc['_id'] = id
#
# File /opt/homebrew/lib/python3.11/site-packages/couchdb/http.py:577, in Resource.put_json(self, path, body, headers, **params)
#     576 def put_json(self, path=None, body=None, headers=None, **params):
# --> 577     return self._request_json('PUT', path, body=body, headers=headers,
#     578                               **params)
#
# File /opt/homebrew/lib/python3.11/site-packages/couchdb/http.py:595, in Resource._request_json(self, method, path, body, headers, **params)
#     594 def _request_json(self, method, path=None, body=None, headers=None, **params):
# --> 595     status, headers, data = self._request(method, path, body=body,
#     596                                           headers=headers, **params)
#     597     if 'application/json' in headers.get('content-type', ''):
#     598         data = json.decode(data.read().decode('utf-8'))
#
# File /opt/homebrew/lib/python3.11/site-packages/couchdb/http.py:590, in Resource._request(self, method, path, body, headers, **params)
#     588 else:
#     589     url = urljoin(self.url, **params)
# --> 590 return self.session.request(method, url, body=body,
#     591                             headers=all_headers,
#     592                             credentials=self.credentials)
#
# File /opt/homebrew/lib/python3.11/site-packages/couchdb/http.py:425, in Session.request(self, method, url, body, headers, credentials, num_redirects)
#     423     raise ResourceNotFound(error)
#     424 elif status == 409:
# --> 425     raise ResourceConflict(error)
#     426 elif status == 412:
#     427     raise PreconditionFailed(error)
#
# ResourceConflict: ('conflict', 'Document update conflict.')

# %%
import requests

url = "http://172.26.131.122:5984/bad_lang_tweet/_design/whatbad/_view/my_view?group=true"
username = "group6"
password = "123456"

response = requests.get(url, auth=(username, password))

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error: {response.status_code}")
# Out:
# {'rows': [{'key': ['Australian Capital Territory (Canberra)', 'ar'], 'value': 143}, {'key': ['Australian Capital Territory (Canberra)', 'art'], 'value': 76}, {'key': ['Australian Capital Territory (Canberra)', 'bg'], 'value': 3}, {'key': ['Australian Capital Territory (Canberra)', 'bn'], 'value': 2}, {'key': ['Australian Capital Territory (Canberra)', 'ca'], 'value': 123}, {'key': ['Australian Capital Territory (Canberra)', 'cs'], 'value': 6}, {'key': ['Australian Capital Territory (Canberra)', 'cy'], 'value': 24}, {'key': ['Australian Capital Territory (Canberra)', 'da'], 'value': 20}, {'key': ['Australian Capital Territory (Canberra)', 'de'], 'value': 81}, {'key': ['Australian Capital Territory (Canberra)', 'el'], 'value': 1}, {'key': ['Australian Capital Territory (Canberra)', 'en'], 'value': 50705}, {'key': ['Australian Capital Territory (Canberra)', 'es'], 'value': 5188}, {'key': ['Australian Capital Territory (Canberra)', 'et'], 'value': 81}, {'key': ['Australian Capital Territory (Canberra)', 'eu'], 'value': 36}, {'key': ['Australian Capital Territory (Canberra)', 'fa'], 'value': 23}, {'key': ['Australian Capital Territory (Canberra)', 'fi'], 'value': 46}, {'key': ['Australian Capital Territory (Canberra)', 'fr'], 'value': 207}, {'key': ['Australian Capital Territory (Canberra)', 'hi'], 'value': 109}, {'key': ['Australian Capital Territory (Canberra)', 'ht'], 'value': 49}, {'key': ['Australian Capital Territory (Canberra)', 'hu'], 'value': 18}, {'key': ['Australian Capital Territory (Canberra)', 'in'], 'value': 809}, {'key': ['Australian Capital Territory (Canberra)', 'is'], 'value': 16}, {'key': ['Australian Capital Territory (Canberra)', 'it'], 'value': 92}, {'key': ['Australian Capital Territory (Canberra)', 'iw'], 'value': 3}, {'key': ['Australian Capital Territory (Canberra)', 'ja'], 'value': 792}, {'key': ['Australian Capital Territory (Canberra)', 'ko'], 'value': 4}, {'key': ['Australian Capital Territory (Canberra)', 'lt'], 'value': 15}, {'key': ['Australian Capital Territory (Canberra)', 'lv'], 'value': 6}, {'key': ['Australian Capital Territory (Canberra)', 'ne'], 'value': 8}, {'key': ['Australian Capital Territory (Canberra)', 'nl'], 'value': 138}, {'key': ['Australian Capital Territory (Canberra)', 'no'], 'value': 27}, {'key': ['Australian Capital Territory (Canberra)', 'pa'], 'value': 2}, {'key': ['Australian Capital Territory (Canberra)', 'pl'], 'value': 32}, {'key': ['Australian Capital Territory (Canberra)', 'pt'], 'value': 133}, {'key': ['Australian Capital Territory (Canberra)', 'qam'], 'value': 81}, {'key': ['Australian Capital Territory (Canberra)', 'qht'], 'value': 44}, {'key': ['Australian Capital Territory (Canberra)', 'qme'], 'value': 331}, {'key': ['Australian Capital Territory (Canberra)', 'qst'], 'value': 25}, {'key': ['Australian Capital Territory (Canberra)', 'ro'], 'value': 23}, {'key': ['Australian Capital Territory (Canberra)', 'ru'], 'value': 14}, {'key': ['Australian Capital Territory (Canberra)', 'sl'], 'value': 5}, {'key': ['Australian Capital Territory (Canberra)', 'sr'], 'value': 11}, {'key': ['Australian Capital Territory (Canberra)', 'sv'], 'value': 30}, {'key': ['Australian Capital Territory (Canberra)', 'th'], 'value': 19}, {'key': ['Australian Capital Territory (Canberra)', 'tl'], 'value': 262}, {'key': ['Australian Capital Territory (Canberra)', 'tr'], 'value': 35}, {'key': ['Australian Capital Territory (Canberra)', 'uk'], 'value': 6}, {'key': ['Australian Capital Territory (Canberra)', 'und'], 'value': 4150}, {'key': ['Australian Capital Territory (Canberra)', 'ur'], 'value': 378}, {'key': ['Australian Capital Territory (Canberra)', 'vi'], 'value': 4}, {'key': ['Australian Capital Territory (Canberra)', 'zh'], 'value': 252}, {'key': ['Australian Capital Territory (Canberra)', 'zxx'], 'value': 219}, {'key': ['Greater Adelaide', 'ar'], 'value': 382}, {'key': ['Greater Adelaide', 'art'], 'value': 158}, {'key': ['Greater Adelaide', 'bg'], 'value': 5}, {'key': ['Greater Adelaide' ...

# %%
file_name = "count_gcc_lang_bad.json"

# Write the JSON object to a file
with open(file_name, "w") as file:
    json.dump(data, file, indent=4)
