# %%
import json
import matplotlib.pyplot as plt
with open('How many curse words per language in each gcc.json', 'r') as f:
    df1 = json.load(f)

with open('What kinds of curse words does each gcc have.json', 'r') as d:
    df2 = json.load(d)

# %%
df2
# Out:
# {'rows': [{'key': ['Australian Capital Territory (Canberra)', 'anal'],
#    'value': 2},
#   {'key': ['Australian Capital Territory (Canberra)', 'arsehole'], 'value': 5},
#   {'key': ['Australian Capital Territory (Canberra)', 'ass'], 'value': 43},
#   {'key': ['Australian Capital Territory (Canberra)', 'asshole'], 'value': 4},
#   {'key': ['Australian Capital Territory (Canberra)', 'bastard'], 'value': 13},
#   {'key': ['Australian Capital Territory (Canberra)', 'bitch'], 'value': 20},
#   {'key': ['Australian Capital Territory (Canberra)', 'bitches'], 'value': 5},
#   {'key': ['Australian Capital Territory (Canberra)', 'blowjob'], 'value': 1},
#   {'key': ['Australian Capital Territory (Canberra)', 'bollocks'], 'value': 1},
#   {'key': ['Australian Capital Territory (Canberra)', 'bondage'], 'value': 1},
#   {'key': ['Australian Capital Territory (Canberra)', 'boner'], 'value': 2},
#   {'key': ['Australian Capital Territory (Canberra)', 'boob'], 'value': 1},
# ...

# %%
# 将 Python 对象写入 CSV 文件
with open('How many curse words per language in each gcc.json', 'w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    
    # 写入 CSV 表头
    writer.writerow(df1[0].keys())
    
    # 写入 CSV 数据行
    for item in data:
        writer.writerow(item.values())
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /Users/zhangwenwen/Desktop/CCC ass2/CCC-ass2-team6/graph data/draw graph.ipynb Cell 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/zhangwenwen/Desktop/CCC%20ass2/CCC-ass2-team6/graph%20data/draw%20graph.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # 将 Python 对象写入 CSV 文件
# ----> <a href='vscode-notebook-cell:/Users/zhangwenwen/Desktop/CCC%20ass2/CCC-ass2-team6/graph%20data/draw%20graph.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> with open('How many curse words per language in each gcc.json', 'w', newline='') as csv_file:
#       <a href='vscode-notebook-cell:/Users/zhangwenwen/Desktop/CCC%20ass2/CCC-ass2-team6/graph%20data/draw%20graph.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a>     writer = csv.writer(csv_file)
# ...
