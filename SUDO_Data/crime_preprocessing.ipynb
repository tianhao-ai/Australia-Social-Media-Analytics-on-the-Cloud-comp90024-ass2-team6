# %%
import pandas as pd

D = pd.read_excel('crime statistics.xlsx')
data = pd.read_excel('crime statistics.xlsx',sheet_name='Table 9')
data.to_csv('crime stat', index=False)

# %%
data
# Out:
#                        Australian Bureau of Statistics       Unnamed: 1  \
# 0                       Recorded Crime – Victims, 2021              NaN
# 1    Released at 11.30am (Canberra time) Thurs 28 J...              NaN
# 2    Table 9 Victims, Selected offences by states a...              NaN
# 3                                              Offence             1993
# 4                                                  NaN  New South Wales
# ..                                                 ...              ...
# 226  (s) Assault data not published for Tasmania fo...              NaN
# 227  (t) Northern Territory data may include victim...              NaN
# 228                                                NaN              NaN
# 229                                                NaN              NaN
# 230                   © Commonwealth of Australia 2022              NaN
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...
